# %% [markdown]
# ### Task [102](https://github.com/salgo60/ProjectOutdoorGyms/issues/102) "uppdater Jönköpings utegym"
#  se även [Notebook Stockholm](https://github.com/salgo60/ProjectOutdoorGyms/issues/99)
#
# * [PSI data Jönköping](https://www.jonkoping.se/psidata)
#   * [API call json](https://gis.jonkoping.se/arcgis/rest/services/OpenData/MapServer/28/query?outFields=*&where=1%3D1&f=geojson)
#
# * [denna notebook](https://github.com/salgo60/ProjectOutdoorGyms/blob/main/Jupyter/Jönköping%20outdoor%20gym.ipynb)
#
# * https://github.com/salgo60/ProjectOutdoorGyms

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2022-05-29 14:37:56.729720

# %%
url="https://gis.jonkoping.se/arcgis/rest/services/OpenData/MapServer/28/query?outFields=*&where=1%3D1&f=geojson"

import urllib3, json
import pandas as pd
from tqdm import tqdm
http = urllib3.PoolManager()
try:
#    r = http.request('POST', url,
#                 headers={'Content-Type': 'application/json'}
#                    )
    print(url)
    r = http.request('GET', url)
except:
    print ("Error and r.status\t",r.status, url)
print("Status\t",r.status,url)
#print(r.data)
# Out:
# https://gis.jonkoping.se/arcgis/rest/services/OpenData/MapServer/28/query?outFields=*&where=1%3D1&f=geojson
# Status	 200 https://gis.jonkoping.se/arcgis/rest/services/OpenData/MapServer/28/query?outFields=*&where=1%3D1&f=geojson

# %%
print(type(r.data)) # Bytes --> need decode 
data = r.data.decode('utf-8')
print(type(data))
data = json.loads(r.data.decode('utf-8'))
#for d in data["features"]:
#    print(d)
# Out:
# <class 'bytes'>
# <class 'str'>

# %%
Utegymdata = pd.DataFrame(data["features"]) 
Utegymdata.keys() 
Utegymdata= pd.json_normalize(data["features"])
Utegymdata.keys()  
Utegymdata
# Out:
#        type     id geometry.type                      geometry.coordinates  \
# 0   Feature     39         Point    [14.06334484418488, 57.77567266850851]
# 1   Feature    278         Point   [14.081823637563552, 57.78504305164521]
# 2   Feature   4013         Point   [14.090468769855846, 57.69231508438181]
# 3   Feature   9974         Point  [14.142792730011719, 57.856385404479774]
# 4   Feature  13716         Point  [14.279260037445983, 57.792274970174354]
# 5   Feature  13717         Point  [14.239839306048625, 57.785068586349944]
# 6   Feature  13718         Point   [14.167207192893946, 57.76696551769888]
# 7   Feature  13719         Point   [14.146257637207016, 57.73914512651033]
# 8   Feature  13720         Point   [14.254597288075166, 57.77408137037559]
# 9   Feature  13722         Point   [14.124288739834942, 57.70066829284151]
# 10  Feature  13723         Point    [14.14907722926921, 57.77508694162006]
# 11  Feature  13725         Point  [13.830224631314325, 57.776037929958434]
# 12  Feature  13726         Point   [14.463551259359836, 58.02684770098175]
# 13  Feature  14527         Point   [14.155127938701659, 57.81139350123127]
# 14  Feature  14528         Point  [14.282724979525838, 57.807787376444644]
# 15  Feature  19754         Point  [14.234468776588644, 57.787723676449005]
# 16  Feature  20963         Point  [14.423755845959274, 57.773639851351405]
# 17  Feature  23408         Point    [14.122576190921897, 57.8646031212834]
# 18  Feature  23409         Point    [14.56763240579445, 58.00685476907677]
# 19  Feature  23808         Point  [14.467958493235733, 58.017977079663375]
# 20  Feature  23809         Point     [14.1249363154389, 57.73258413096174]
# 21  Feature  29013         Point    [14.13766960124456, 57.77904463123033]
# 22  Feature  29014         Point   [14.180344533405664, 57.77380126838164]
# 23  Feature  31415         Point    [14.31684906291698, 57.70063587665647]
# 24  Feature  33816         Point   [14.490797895378156, 57.93596649250235]
# 25  Feature  55057         Point   [14.232015421350972, 57.76629948605729]
# 26  Feature  55853         Point  [14.162420690537726, 57.775364462890636]
#
#     properties.OBJECTID                        properties.name  \
# 0                    39                     Axamobadet: utegym
# 1                   278                  IF Hallby SOK: utegym
# 2                  4013                  Jönköpings OK: utegym
# 3                  9974  Bankeryds skid o motionsklubb: utegym
# 4                 13716                            Esplanaden
# 5                 13717               Ängens Arena, Österängen
# 6                 13718               Munksjöstrandens: utegym
# 7                 13719            Puls Arena, Råslätt: utegym
# 8                 13720             Friluftsfrämjandet: utegym
# 9                 13722        Norrahammar GIS: Utegym Flahult
# 10                13723                            Friaredalen
# 11                13725                  Bottnaryds IF: utegym
# 12                13726                      Hamnvägen: utegym
# 13                14527                            Strandängen
# 14                14528                           IKHP: utegym
# 15                19754                         Ravinen utegym
# 16                20963           Lekeryd Svarttorp SK: utegym
# 17                23408      Bankeryds SK/Bankeryds TK: utegym
# 18                23409                  Örserumsbadet: utegym
# 19                23808               Grännabygdens OK: utegym
# 20                23809                   Hovslätts IK: utegym
# 21                29013                    Stadsparkens utegym
# 22                29014                 Kålgårdsparkens utegym
# 23                31415                   Tenhults SOK: utegym
# 24                33816                    Bauergårdens utegym
# 25                55057                     Järabackens utegym
# 26                55853                   Munksjökajens utegym
#
#     properties.type properties.descr  \
# 0                35
# 1                35             None
# 2                35             None
# 3                35             None
# 4                35
# 5                35
# 6                35
# 7                35
# 8                35
# 9                35
# 10               35
# 11               35
# 12               35
# 13               35             None
# 14               35             None
# 15               35             None
# 16               35             None
# 17               35             None
# 18               35             None
# 19               35             None
# 20               35             None
# 21               35             None
# 22               35             None
# 23               35             None
# 24               35             None
# 25               35             None
# 26               35             None
#
#                                       properties.link  \
# 0                                                None
# 1   https://www.jonkoping.se/upplevagora/friluftsl...
# 2                        https://www.jonkopingsok.nu/
# 3                           https://www.laget.se/BSMK
# 4   https://www.jonkoping.se/upplevagora/friluftsl...
# 5   https://www.jonkoping.se/upplevagora/friluftsl...
# 6   https://www.jonkoping.se/upplevagora/friluftsl...
# 7   https://www.jonkoping.se/upplevagora/friluftsl...
# 8   https://www.jonkoping.se/upplevagora/friluftsl...
# 9                           https://www.laget.se/NGIS
# 10  https://www.jonkoping.se/upplevagora/friluftsl...
# 11        http://www.bottnarydsif.se/start/?ID=234915
# 12  https://www.jonkoping.se/upplevagora/friluftsl...
# 13  https://www.jonkoping.se/upplevagora/friluftsl...
# 14  https://www.jonkoping.se/upplevagora/friluftsl...
# 15  https://www.jonkoping.se/upplevagora/friluftsl...
# 16                                               None
# 17                  https://www.laget.se/Bankeryds_SK
# 18  https://www.jonkoping.se/upplevagora/friluftsl...
# 19  https://idrottonline.se/Granna-BygdensOK-Orien...
# 20  https://www.jonkoping.se/upplevagora/friluftsl...
# 21  https://www.jonkoping.se/upplevagora/friluftsl...
# 22  https://www.jonkoping.se/upplevagora/friluftsl...
# 23                               https://www.tsok.nu/
# 24                         http://www.bauergarden.se/
# 25                                               None
# 26                                               None
#
#     properties.ModificationDate  properties.oppnadata properties.tillg_lank  \
# 0                 1652078762000                     1                  None
# 1                 1605102040000                     1                  None
# 2                 1602248031000                     1                  None
# 3                 1602248035000                     1                  None
# 4                 1602248088000                     1                  None
# 5                 1602248082000                     1                  None
# 6                 1602248089000                     1                  None
# 7                 1602248051000                     1                  None
# 8                 1602248054000                     1                  None
# 9                 1602248038000                     1                  None
# 10                1602248092000                     1                  None
# 11                1602248041000                     1                  None
# 12                1602248043000                     1                  None
# 13                1602248086000                     1                  None
# 14                1602248058000                     1                  None
# 15                1602248061000                     1                  None
# 16                1602248063000                     1                  None
# 17                1614580982000                     1                  None
# 18                1602248071000                     1                  None
# 19                1602248073000                     1                  None
# 20                1602248076000                     1                  None
# 21                1608014700000                     1                  None
# 22                1602248101000                     1                  None
# 23                1602248046000                     1                  None
# 24                1602248079000                     1                  None
# 25                1636103462000                     1                  None
# 26                1637329262000                     1                  None
#
#     properties.Friluftsliv properties.Bild
# 0                        1            None
# 1                        1            None
# 2                        1            None
# 3                        1            None
# 4                        0            None
# 5                        0            None
# 6                        0            None
# 7                        1            None
# 8                        1            None
# 9                        1            None
# 10                       0            None
# 11                       1            None
# 12                       1            None
# 13                       0            None
# 14                       1            None
# 15                       1            None
# 16                       1            None
# 17                       1            None
# 18                       1            None
# 19                       1            None
# 20                       1            None
# 21                       1            None
# 22                       0            None
# 23                       1            None
# 24                       1            None
# 25                       1            None
# 26                       1            None

# %% [markdown]
# ### Status JSON
# * fular och lägger in **ID** i Wikidata [P217]() precis som jag gjorde med Stockholm --> kan enkelt kolla diff
# * see [notebook Stockholm](https://github.com/salgo60/ProjectOutdoorGyms/blob/main/Jupyter/Stockholm%20outdoor%20gym.ipynb) med 100 utegym och bra flöde av nya....

# %%
Utegymdata.to_csv("Jönköping_gym.csv")

# %% [markdown]
# ### SPARQL Wikidata
# Hämta utegym i WD för Jönköpings kommun [wd:Q504689](https://www.wikidata.org/wiki/Q504689?uselang=sv)
# * [SPARQL](https://w.wiki/5DRu) Wikidata Jönköping

# %%
# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"
 
# SPARQL https://w.wiki/5DRu
queryUppsala = """SELECT distinct ?inception ?item ?itemLabel ?www ?id ?API  WHERE {
  # ?item wdt:P6104 wd:Q107186275.
  OPTIONAL {?item wdt:P571 ?inception}
  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "sv,en,de" . 
  }
  
OPTIONAL{?item wdt:P571 ?date}
OPTIONAL { ?item wdt:P18 ?img}
# ?item wdt:P131 wd:Q504689  # kommun
OPTIONAL { ?item wdt:P856 ?www. }
OPTIONAL { ?item wdt:P625 ?coord. }
OPTIONAL { ?item wdt:P217 ?id. }
} order by desc(?date)"""


def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

def get_sparql_dataframe(endpoint_url, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    user_agent = "salgo60/%s.%s" % (sys.version_info[0], sys.version_info[1])
 
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

WDtotOutdoorGym = get_sparql_dataframe(endpoint_url, queryUppsala)

WDtotOutdoorGym
# Out:
#    inception                                       item  \
# 0       None  http://www.wikidata.org/entity/Q107400912
# 1       None  http://www.wikidata.org/entity/Q107407072
# 2       None  http://www.wikidata.org/entity/Q107407136
# 3       None  http://www.wikidata.org/entity/Q107407139
# 4       None  http://www.wikidata.org/entity/Q107407247
# 5       None  http://www.wikidata.org/entity/Q107407248
# 6       None  http://www.wikidata.org/entity/Q107407249
# 7       None  http://www.wikidata.org/entity/Q107407250
# 8       None  http://www.wikidata.org/entity/Q107407251
# 9       None  http://www.wikidata.org/entity/Q107407252
# 10      None  http://www.wikidata.org/entity/Q107407253
# 11      None  http://www.wikidata.org/entity/Q107407254
# 12      None  http://www.wikidata.org/entity/Q107407255
# 13      None  http://www.wikidata.org/entity/Q107407256
# 14      None  http://www.wikidata.org/entity/Q107407257
# 15      None  http://www.wikidata.org/entity/Q107407258
# 16      None  http://www.wikidata.org/entity/Q107407259
# 17      None  http://www.wikidata.org/entity/Q107407260
# 18      None  http://www.wikidata.org/entity/Q107407261
# 19      None  http://www.wikidata.org/entity/Q107407262
# 20      None  http://www.wikidata.org/entity/Q107407263
# 21      None  http://www.wikidata.org/entity/Q107407264
# 22      None  http://www.wikidata.org/entity/Q107407266
# 23      None  http://www.wikidata.org/entity/Q107407267
# 24      None  http://www.wikidata.org/entity/Q107407268
# 25      None  http://www.wikidata.org/entity/Q107407270
# 26      None  http://www.wikidata.org/entity/Q107407271
# 27      None  http://www.wikidata.org/entity/Q107407272
#
#                                 itemLabel  \
# 0             Öxnegården, Öxnehaga utegym
# 1                         Örserum, utegym
# 2                    Axamo motion: utegym
# 3                     Stadsparkens utegym
# 4                   IF Hallby SOK: utegym
# 5                   Jönköpings OK: utegym
# 6   Bankeryds skid o motionsklubb: utegym
# 7                      Esplanaden, utegym
# 8                Ängens Arena, Österängen
# 9                Munksjöstrandens: utegym
# 10            Puls Arena, Råslätt: utegym
# 11             Friluftsfrämjandet: utegym
# 12                   Puls Arena, Öxnehaga
# 13        Norrahammar GIS: Utegym Flahult
# 14                    Friaredalen, utegym
# 15                  Bottnaryds IF: utegym
# 16                      Hamnvägen: utegym
# 17                    Strandängen, utegym
# 18                           IKHP: utegym
# 19                         Ravinen utegym
# 20           Lekeryd Svarttorp SK: utegym
# 21      Bankeryds SK/Bankeryds TK: utegym
# 22                  Örserumsbadet: utegym
# 23               Grännabygdens OK: utegym
# 24                   Hovslätts IK: utegym
# 25                 Kålgårdsparkens utegym
# 26                   Tenhults SOK: utegym
# 27                    Bauergårdens utegym
#
#                                                   www     id   API
# 0      https://naturkartan.se/sv/jonkoping/oxnegarden   None  None
# 1   https://www.jonkoping.se/upplevagora/friluftsl...   None  None
# 2   https://www.jonkoping.se/upplevagora/friluftsl...     39  None
# 3   https://www.jonkoping.se/upplevagora/friluftsl...  29013  None
# 4   https://www.jonkoping.se/upplevagora/friluftsl...    278  None
# 5                        https://www.jonkopingsok.nu/   4013  None
# 6                           https://www.laget.se/BSMK   9974  None
# 7   https://www.jonkoping.se/upplevagora/friluftsl...  13716  None
# 8   https://www.jonkoping.se/upplevagora/friluftsl...  13717  None
# 9   https://www.jonkoping.se/upplevagora/friluftsl...  13718  None
# 10  https://www.jonkoping.se/upplevagora/friluftsl...  13719  None
# 11  https://www.jonkoping.se/upplevagora/friluftsl...  13720  None
# 12  https://www.jonkoping.se/upplevagora/friluftsl...   None  None
# 13                          https://www.laget.se/NGIS  13722  None
# 14  https://www.jonkoping.se/upplevagora/friluftsl...  13723  None
# 15        http://www.bottnarydsif.se/start/?ID=234915  13725  None
# 16  https://www.jonkoping.se/upplevagora/friluftsl...  13726  None
# 17  https://www.jonkoping.se/upplevagora/friluftsl...  13727  None
# 18  https://www.jonkoping.se/upplevagora/friluftsl...  13728  None
# 19  https://www.jonkoping.se/upplevagora/friluftsl...  19754  None
# 20                                               None  20963  None
# 21                  https://www.laget.se/Bankeryds_SK  23408  None
# 22  https://www.jonkoping.se/upplevagora/friluftsl...  23409  None
# 23  https://idrottonline.se/Granna-BygdensOK-Orien...  23808  None
# 24  https://www.jonkoping.se/upplevagora/friluftsl...  23809  None
# 25  https://www.jonkoping.se/upplevagora/friluftsl...  29014  None
# 26                               https://www.tsok.nu/  31415  None
# 27                         http://www.bauergarden.se/  33816  None

# %%
WDtotOutdoorGym.isnull().sum(), WDtotOutdoorGym.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   inception  0 non-null      object
#  1   item       28 non-null     object
#  2   itemLabel  28 non-null     object
#  3   www        27 non-null     object
#  4   id         25 non-null     object
#  5   API        0 non-null      object
# dtypes: object(6)
# memory usage: 1.4+ KB
# (inception    28
#  item          0
#  itemLabel     0
#  www           1
#  id            3
#  API          28
#  dtype: int64,
#  None)

# %%
#WDUppsalaNew = WDtotOutdoorGym.rename(columns={'id': 'properties.ID'})

# %%
WDtotOutdoorGym[["id"]] = WDtotOutdoorGym[["id"]].apply(pd.to_numeric)

# %%
Utegymdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   type                         27 non-null     object
#  1   id                           27 non-null     int64
#  2   geometry.type                27 non-null     object
#  3   geometry.coordinates         27 non-null     object
#  4   properties.OBJECTID          27 non-null     int64
#  5   properties.name              27 non-null     object
#  6   properties.type              27 non-null     int64
#  7   properties.descr             10 non-null     object
#  8   properties.link              23 non-null     object
#  9   properties.ModificationDate  27 non-null     int64
#  10  properties.oppnadata         27 non-null     int64
#  11  properties.tillg_lank        0 non-null      object
#  12  properties.Friluftsliv       27 non-null     int64
#  13  properties.Bild              0 non-null      object
# dtypes: int64(6), object(8)
# memory usage: 3.1+ KB

# %%
OutdoorGym_diff = pd.merge(WDtotOutdoorGym,Utegymdata, how='outer', indicator='Exist')

# %%
OutdoorGym_diff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   inception                    0 non-null      object
#  1   item                         28 non-null     object
#  2   itemLabel                    28 non-null     object
#  3   www                          27 non-null     object
#  4   id                           29 non-null     float64
#  5   API                          0 non-null      object
#  6   type                         27 non-null     object
#  7   geometry.type                27 non-null     object
#  8   geometry.coordinates         27 non-null     object
#  9   properties.OBJECTID          27 non-null     float64
#  10  properties.name              27 non-null     object
#  11  properties.type              27 non-null     float64
#  12  properties.descr             10 non-null     object
#  13  properties.link              23 non-null     object
#  14  properties.ModificationDate  27 non-null     float64
#  15  properties.oppnadata         27 non-null     float64
#  16  properties.tillg_lank        0 non-null      object
#  17  properties.Friluftsliv       27 non-null     float64
#  18  properties.Bild              0 non-null      object
#  19  Exist                        32 non-null     category
# dtypes: category(1), float64(6), object(13)
# memory usage: 5.2+ KB

# %%
OutdoorGym_diff["Exist"].value_counts()
# Out:
# both          23
# left_only      5
# right_only     4
# Name: Exist, dtype: int64

# %%
#where Wikidata miss an ID in OutdoorGym_diff
MissingGymsWD = OutdoorGym_diff[OutdoorGym_diff["Exist"] == "right_only"]

# %% [markdown]
# ### Saknas i wikidata

# %%
MissingGymsWD
# Out:
#    inception item itemLabel  www       id  API     type geometry.type  \
# 28       NaN  NaN       NaN  NaN  14527.0  NaN  Feature         Point
# 29       NaN  NaN       NaN  NaN  14528.0  NaN  Feature         Point
# 30       NaN  NaN       NaN  NaN  55057.0  NaN  Feature         Point
# 31       NaN  NaN       NaN  NaN  55853.0  NaN  Feature         Point
#
#                         geometry.coordinates  properties.OBJECTID  \
# 28   [14.155127938701659, 57.81139350123127]              14527.0
# 29  [14.282724979525838, 57.807787376444644]              14528.0
# 30   [14.232015421350972, 57.76629948605729]              55057.0
# 31  [14.162420690537726, 57.775364462890636]              55853.0
#
#          properties.name  properties.type properties.descr  \
# 28           Strandängen             35.0             None
# 29          IKHP: utegym             35.0             None
# 30    Järabackens utegym             35.0             None
# 31  Munksjökajens utegym             35.0             None
#
#                                       properties.link  \
# 28  https://www.jonkoping.se/upplevagora/friluftsl...
# 29  https://www.jonkoping.se/upplevagora/friluftsl...
# 30                                               None
# 31                                               None
#
#     properties.ModificationDate  properties.oppnadata properties.tillg_lank  \
# 28                 1.602248e+12                   1.0                  None
# 29                 1.602248e+12                   1.0                  None
# 30                 1.636103e+12                   1.0                  None
# 31                 1.637329e+12                   1.0                  None
#
#     properties.Friluftsliv properties.Bild       Exist
# 28                     0.0            None  right_only
# 29                     1.0            None  right_only
# 30                     1.0            None  right_only
# 31                     1.0            None  right_only

# %%
MissingGymsKommun = OutdoorGym_diff[OutdoorGym_diff["Exist"] == "left_only"]
MissingGymsKommun
# Out:
#    inception                                       item  \
# 0       None  http://www.wikidata.org/entity/Q107400912
# 1       None  http://www.wikidata.org/entity/Q107407072
# 2       None  http://www.wikidata.org/entity/Q107407255
# 17      None  http://www.wikidata.org/entity/Q107407260
# 18      None  http://www.wikidata.org/entity/Q107407261
#
#                       itemLabel  \
# 0   Öxnegården, Öxnehaga utegym
# 1               Örserum, utegym
# 2          Puls Arena, Öxnehaga
# 17          Strandängen, utegym
# 18                 IKHP: utegym
#
#                                                   www       id   API type  \
# 0      https://naturkartan.se/sv/jonkoping/oxnegarden      NaN  None  NaN
# 1   https://www.jonkoping.se/upplevagora/friluftsl...      NaN  None  NaN
# 2   https://www.jonkoping.se/upplevagora/friluftsl...      NaN  None  NaN
# 17  https://www.jonkoping.se/upplevagora/friluftsl...  13727.0  None  NaN
# 18  https://www.jonkoping.se/upplevagora/friluftsl...  13728.0  None  NaN
#
#    geometry.type geometry.coordinates  properties.OBJECTID properties.name  \
# 0            NaN                  NaN                  NaN             NaN
# 1            NaN                  NaN                  NaN             NaN
# 2            NaN                  NaN                  NaN             NaN
# 17           NaN                  NaN                  NaN             NaN
# 18           NaN                  NaN                  NaN             NaN
#
#     properties.type properties.descr properties.link  \
# 0               NaN              NaN             NaN
# 1               NaN              NaN             NaN
# 2               NaN              NaN             NaN
# 17              NaN              NaN             NaN
# 18              NaN              NaN             NaN
#
#     properties.ModificationDate  properties.oppnadata properties.tillg_lank  \
# 0                           NaN                   NaN                   NaN
# 1                           NaN                   NaN                   NaN
# 2                           NaN                   NaN                   NaN
# 17                          NaN                   NaN                   NaN
# 18                          NaN                   NaN                   NaN
#
#     properties.Friluftsliv properties.Bild      Exist
# 0                      NaN             NaN  left_only
# 1                      NaN             NaN  left_only
# 2                      NaN             NaN  left_only
# 17                     NaN             NaN  left_only
# 18                     NaN             NaN  left_only

# %%
# Brukar vara en "dum" tanke att kommunen bara visar sina utegym inte andras som är gratis...
# Med brasklappen att Wikidata kan alla redigera och datat kan vara fel
MissingGymsKommun[["item","itemLabel","www"]]
# Out:
#                                          item                    itemLabel  \
# 0   http://www.wikidata.org/entity/Q107400912  Öxnegården, Öxnehaga utegym
# 1   http://www.wikidata.org/entity/Q107407072              Örserum, utegym
# 2   http://www.wikidata.org/entity/Q107407255         Puls Arena, Öxnehaga
# 17  http://www.wikidata.org/entity/Q107407260          Strandängen, utegym
# 18  http://www.wikidata.org/entity/Q107407261                 IKHP: utegym
#
#                                                   www
# 0      https://naturkartan.se/sv/jonkoping/oxnegarden
# 1   https://www.jonkoping.se/upplevagora/friluftsl...
# 2   https://www.jonkoping.se/upplevagora/friluftsl...
# 17  https://www.jonkoping.se/upplevagora/friluftsl...
# 18  https://www.jonkoping.se/upplevagora/friluftsl...

# %%
end = datetime.now()
print("Ended: ", end) 
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
# Out:
# Ended:  2022-05-29 14:37:59.380198
# Time elapsed (hh:mm:ss.ms) 0:00:02.654585
