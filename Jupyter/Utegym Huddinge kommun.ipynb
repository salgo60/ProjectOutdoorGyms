# %% [markdown]
# ## Huddinge kommun
# * denna [Notebook](https://github.com/salgo60/ProjectOutdoorGyms/blob/main/Jupyter/Utegym%20Huddinge%20kommun.ipynb)
# * GITHUB [ProjectOutdoorGyms](https://github.com/salgo60/ProjectOutdoorGyms)
#   * [ProjectOutdoorGyms/issues/56](https://github.com/salgo60/ProjectOutdoorGyms/issues/56) Huddinge kommun
#
# ## Kommentar
# 1. bra om varje gym har ett unikt id så vi kan enklare jämföra om vi har detta utegym bland de [1200 vi hittat karta](https://w.wiki/3wJS) / [Wikidata:WikiProject_Outdoor_Gyms](https://www.wikidata.org/wiki/Wikidata:WikiProject_Outdoor_Gyms) och hantera om utegym ändrar plats, upphör, ändrar namn
#   1. en variant är att ni har samma som Wikidata i ert data se [lista](https://w.wiki/3ww4)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2021-08-24 10:35:49.956844

# %%
import pandas as pd 
url = "https://metadatakatalog.huddinge.se/store/23/resource/626"

utegymHuddinge = pd.json_normalize(pd.read_json(url)['features']) 
utegymHuddinge
# Out:
#       type geometry.type                 geometry.coordinates  \
# 0  Feature         Point     [148026.9, 6572331.390000001, 0]
# 1  Feature         Point           [147185.43, 6570357.45, 0]
# 2  Feature         Point    [149788.74, 6570381.529999999, 0]
# 3  Feature         Point           [149275.62, 6569397.63, 0]
# 4  Feature         Point    [158312.97, 6567754.680000001, 0]
# 5  Feature         Point           [158980.44, 6568762.71, 0]
# 6  Feature         Point           [147798.45, 6566675.55, 0]
# 7  Feature         Point           [148474.11, 6564112.89, 0]
# 8  Feature         Point    [155954.28, 6567599.399999999, 0]
# 9  Feature         Point  [143109.2834473, 6571586.643219, 0]
#
#       properties.plats                        properties.namn  \
# 0           Tranparken                Naturgym vid Tranparken
# 1        Källbrinks IP              Utegym vid Källbrinks IP
# 2     Skeppsmyreparken              Utegym i Skeppsmyreparken
# 3           Rådsparken                    Utegym i Rådsparken
# 4        Nytorps mosse  Hinderbana och utegym i Nytorps mosse
# 5        Sjöängsparken                 Utegym i Sjöängsparken
# 6             Visättra      Naturgym vid Visättra sportcenter
# 7       Gladö lekplats              Utegym vid Gladö lekplats
# 8               Ågesta                  Ågesta friluftsområde
# 9  Vårby Herrgårdspark           Utegym i Vårby Herrgårdspark
#
#   properties.parkeringsplatser properties.namn_pa_agare  \
# 0                          Nej          Huddinge kommun
# 1                                       Huddinge kommun
# 2                                       Huddinge kommun
# 3                                       Huddinge kommun
# 4                           Ja          Huddinge kommun
# 5                           Ja          Huddinge kommun
# 6                           Ja          Huddinge kommun
# 7                           Ja          Huddinge kommun
# 8                                        Stockholm stad
# 9                                       Huddinge kommun
#
#   properties.telefonnummer     properties.e_post  \
# 0         +46 853 53 00 00  huddinge@huddinge.se
# 1         +46 853 53 00 00  huddinge@huddinge.se
# 2         +46 853 53 00 00  huddinge@huddinge.se
# 3         +46 853 53 00 00  huddinge@huddinge.se
# 4         +46 853 53 00 00  huddinge@huddinge.se
# 5         +46 853 53 00 00  huddinge@huddinge.se
# 6         +46 853 53 00 00  huddinge@huddinge.se
# 7         +46 853 53 00 00  huddinge@huddinge.se
# 8
# 9           08-53 53 00 00
#
#             properties.vagbeskrivning properties.belysning  \
# 0             Tranvägen 14, Segeltorp                   Ja
# 1  Gamla Stockholmsvägen 91, Huddinge
# 2       Stationsvägen 16-18, Huddinge                   Ja
# 3              Rådsvägen 17, Huddinge
# 4          Kvartettvägen 8, Trångsund                   Ja
# 5          Sjöängsvägen 15, Trångsund                   Ja
# 6         Kvarnängsvägen 12, Visättra                   Ja
# 7          Nyboviksvägen 23, Huddinge
# 8                  Bonäsvägen, Farsta
# 9                                                       Ja
#
#   properties.rullstolanpassat properties.postnummer  \
# 0                                            141 72
# 1                                            141 32
# 2                                            141 40
# 3                                            141 85
# 4                   Begränsat                142 63
# 5                   Begränsat                142 64
# 6                   Begränsat                141 49
# 7                   Begränsat                141 91
# 8                                            123 52
# 9                                            143 46
#
#                                      properties.lank properties.Uppdaterad
# 0  https://www.huddinge.se/fritid-natur-och-kultu...              20210823
# 1  https://www.huddinge.se/fritid-natur-och-kultu...              20210823
# 2  https://www.huddinge.se/fritid-natur-och-kultu...              20210823
# 3  https://www.huddinge.se/fritid-natur-och-kultu...              20210823
# 4  https://www.huddinge.se/fritid-natur-och-kultu...              20210823
# 5  https://www.huddinge.se/fritid-natur-och-kultu...              20210823
# 6  https://www.huddinge.se/fritid-natur-och-kultu...              20210823
# 7  https://www.huddinge.se/fritid-natur-och-kultu...              20210823
# 8  https://www.huddinge.se/fritid-natur-och-kultu...              20210823
# 9                                                                 20210823

# %%
utegymHuddinge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   type                          10 non-null     object
#  1   geometry.type                 10 non-null     object
#  2   geometry.coordinates          10 non-null     object
#  3   properties.plats              10 non-null     object
#  4   properties.namn               10 non-null     object
#  5   properties.parkeringsplatser  10 non-null     object
#  6   properties.namn_pa_agare      10 non-null     object
#  7   properties.telefonnummer      10 non-null     object
#  8   properties.e_post             10 non-null     object
#  9   properties.vagbeskrivning     10 non-null     object
#  10  properties.belysning          10 non-null     object
#  11  properties.rullstolanpassat   10 non-null     object
#  12  properties.postnummer         10 non-null     object
#  13  properties.lank               10 non-null     object
#  14  properties.Uppdaterad         10 non-null     object
# dtypes: object(15)
# memory usage: 1.3+ KB

# %%
utegymHuddinge[{"properties.Uppdaterad","properties.namn","properties.lank","properties.plats","geometry.coordinates"}]. \
    sort_values(by="properties.namn")
# Out:
#                          properties.namn                 geometry.coordinates  \
# 4  Hinderbana och utegym i Nytorps mosse    [158312.97, 6567754.680000001, 0]
# 0                Naturgym vid Tranparken     [148026.9, 6572331.390000001, 0]
# 6      Naturgym vid Visättra sportcenter           [147798.45, 6566675.55, 0]
# 3                    Utegym i Rådsparken           [149275.62, 6569397.63, 0]
# 5                 Utegym i Sjöängsparken           [158980.44, 6568762.71, 0]
# 2              Utegym i Skeppsmyreparken    [149788.74, 6570381.529999999, 0]
# 9           Utegym i Vårby Herrgårdspark  [143109.2834473, 6571586.643219, 0]
# 7              Utegym vid Gladö lekplats           [148474.11, 6564112.89, 0]
# 1              Utegym vid Källbrinks IP            [147185.43, 6570357.45, 0]
# 8                  Ågesta friluftsområde    [155954.28, 6567599.399999999, 0]
#
#   properties.Uppdaterad     properties.plats  \
# 4              20210823        Nytorps mosse
# 0              20210823           Tranparken
# 6              20210823             Visättra
# 3              20210823           Rådsparken
# 5              20210823        Sjöängsparken
# 2              20210823     Skeppsmyreparken
# 9              20210823  Vårby Herrgårdspark
# 7              20210823       Gladö lekplats
# 1              20210823        Källbrinks IP
# 8              20210823               Ågesta
#
#                                      properties.lank
# 4  https://www.huddinge.se/fritid-natur-och-kultu...
# 0  https://www.huddinge.se/fritid-natur-och-kultu...
# 6  https://www.huddinge.se/fritid-natur-och-kultu...
# 3  https://www.huddinge.se/fritid-natur-och-kultu...
# 5  https://www.huddinge.se/fritid-natur-och-kultu...
# 2  https://www.huddinge.se/fritid-natur-och-kultu...
# 9
# 7  https://www.huddinge.se/fritid-natur-och-kultu...
# 1  https://www.huddinge.se/fritid-natur-och-kultu...
# 8  https://www.huddinge.se/fritid-natur-och-kultu...

# %% [markdown]
# ## Wikidata

# %%
# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys,json
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"

# https://w.wiki/3ww2
queryHuddingeUtegum = """SELECT DISTINCT (REPLACE(STR(?entity), ".*Q", "Q") AS ?qid) ?entity ?entityLabel ?coord ?www WHERE {
  # ?entity (wdt:P6104/(wdt:P361*)) wd:Q107186275;
    wdt:P17 wd:Q34;
    wdt:P131 wd:Q492575.
  OPTIONAL {?entity wdt:P625 ?coord}
  OPTIONAL {?entity wdt:P856 ?www}
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
} order by ?entityLabel"""



def get_sparql_dataframe(endpoint_url, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    user_agent = "salgo60/%s.%s" % (sys.version_info[0], sys.version_info[1])
 
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

WDHuddinge = get_sparql_dataframe(endpoint_url, queryHuddingeUtegum)
WDHuddinge.shape
# Out:
# (12, 5)

# %%
WDHuddinge
# Out:
#            qid                                     entity  \
# 0   Q107208250  http://www.wikidata.org/entity/Q107208250
# 1   Q107208246  http://www.wikidata.org/entity/Q107208246
# 2   Q107725182  http://www.wikidata.org/entity/Q107725182
# 3   Q107723147  http://www.wikidata.org/entity/Q107723147
# 4   Q107208242  http://www.wikidata.org/entity/Q107208242
# 5   Q107208240  http://www.wikidata.org/entity/Q107208240
# 6   Q107208249  http://www.wikidata.org/entity/Q107208249
# 7   Q107208245  http://www.wikidata.org/entity/Q107208245
# 8   Q107208248  http://www.wikidata.org/entity/Q107208248
# 9   Q107208243  http://www.wikidata.org/entity/Q107208243
# 10  Q107723880  http://www.wikidata.org/entity/Q107723880
# 11  Q107208252  http://www.wikidata.org/entity/Q107208252
#
#                               entityLabel                       coord  \
# 0                  Gladö lekplats, utegym  Point(17.973302 59.192496)
# 1   Hinderbana och utegym i Nytorps mosse  Point(18.145586 59.225109)
# 2          Huddinge sjukhusområde, utegym    Point(17.93268 59.21915)
# 3             Högskolebiblioteket, utegym  Point(17.987308 59.239938)
# 4                   Källbrinks IP, utegym  Point(17.950673 59.248545)
# 5                 Naturgym vid Tranparken  Point(17.965402 59.266269)
# 6       Naturgym vid Visättra sportcenter  Point(17.961454 59.215498)
# 7                      Rådsparken, utegym  Point(17.987308 59.239938)
# 8                   Sjöängsparken, utegym  Point(18.157318 59.234144)
# 9                Skeppsmyreparken, utegym  Point(17.996297 59.248771)
# 10           Vårby herrgårdspark , utegym    Point(17.87922 59.25946)
# 11                  Ågesta friluftsområde  Point(18.104274 59.223755)
#
#                                                   www
# 0   https://www.huddinge.se/fritid-natur-och-kultu...
# 1   https://www.huddinge.se/fritid-natur-och-kultu...
# 2   https://www.locum.se/husen/huddinge-sjukhusomr...
# 3   https://www.sh.se/student/hur-gor-jag/tranings...
# 4   https://www.huddinge.se/fritid-natur-och-kultu...
# 5   https://www.huddinge.se/fritid-natur-och-kultu...
# 6   https://www.huddinge.se/fritid-natur-och-kultu...
# 7   https://www.huddinge.se/fritid-natur-och-kultu...
# 8   https://www.huddinge.se/fritid-natur-och-kultu...
# 9   https://www.huddinge.se/fritid-natur-och-kultu...
# 10  https://www.huddinge.se/fritid-natur-och-kultu...
# 11  https://www.huddinge.se/fritid-natur-och-kultu...
